# %% [markdown]
# Step 1: Download FaceSwap videos

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import random
import os
from tqdm import tqdm
import time

api = KaggleApi()
api.authenticate()

dataset = "xdxd003/ff-c23"

all_files = []
page_token = None
while True:
    result = api.dataset_list_files(dataset, page_token=page_token, page_size=500)
    all_files.extend(result.files)
    page_token = result.next_page_token
    if not page_token:
        break

faceswap_files = [f.name for f in all_files if f.name.startswith("FaceForensics++_C23/FaceSwap/")]
print(f"FaceSwap videos found: {len(faceswap_files)}")

random.seed(42)
SAMPLE_SIZE = 1000
sampled_faceswap = random.sample(faceswap_files, min(SAMPLE_SIZE, len(faceswap_files)))
print(f"Selected {len(sampled_faceswap)} FaceSwap videos")

faceswap_dest = "D:/Deepfake-detection/datasets/raw_faceswap"
os.makedirs(faceswap_dest, exist_ok=True)

def download_with_retry(filenames, dest_folder, max_retries=3):
    existing = set(os.listdir(dest_folder))
    for filename in tqdm(filenames):
        local_name = filename.split("/")[-1]
        if local_name in existing:
            continue
        attempt = 0
        while attempt < max_retries:
            try:
                api.dataset_download_file(dataset, file_name=filename, path=dest_folder)
                break
            except Exception as e:
                attempt += 1
                if attempt == max_retries:
                    print(f"FAILED after {max_retries} attempts: {filename} -> {e}")
                else:
                    time.sleep(3)

print("Downloading FaceSwap videos...")
download_with_retry(sampled_faceswap, faceswap_dest)
print(f"FaceSwap videos on disk: {len(os.listdir(faceswap_dest))}")
# Out:
# FaceSwap videos found: 1000
# Selected 1000 FaceSwap videos
# Downloading FaceSwap videos...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   0%|          | 1/1000 [00:04<1:18:15,  4.70s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   0%|          | 2/1000 [00:09<1:16:34,  4.60s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   0%|          | 3/1000 [00:15<1:28:46,  5.34s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   0%|          | 4/1000 [00:24<1:52:03,  6.75s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   0%|          | 5/1000 [00:29<1:44:32,  6.30s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|          | 6/1000 [00:38<1:57:44,  7.11s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|          | 7/1000 [00:45<1:54:57,  6.95s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|          | 8/1000 [00:50<1:44:14,  6.30s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|          | 9/1000 [00:55<1:42:04,  6.18s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|          | 10/1000 [01:00<1:31:29,  5.55s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|          | 11/1000 [01:04<1:25:23,  5.18s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|          | 12/1000 [01:08<1:18:58,  4.80s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|▏         | 13/1000 [01:12<1:13:29,  4.47s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   1%|▏         | 14/1000 [01:16<1:12:15,  4.40s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 15/1000 [01:20<1:10:23,  4.29s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 16/1000 [01:24<1:09:35,  4.24s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 17/1000 [01:27<1:04:44,  3.95s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 18/1000 [01:32<1:10:36,  4.31s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 19/1000 [01:37<1:10:26,  4.31s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 20/1000 [01:43<1:18:45,  4.82s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 21/1000 [01:48<1:19:04,  4.85s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 22/1000 [01:51<1:13:48,  4.53s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 23/1000 [01:56<1:14:46,  4.59s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▏         | 24/1000 [02:01<1:17:10,  4.74s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   2%|▎         | 25/1000 [02:05<1:11:44,  4.41s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   3%|▎         | 26/1000 [02:10<1:13:58,  4.56s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   3%|▎         | 27/1000 [02:14<1:10:04,  4.32s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   3%|▎         | 28/1000 [02:18<1:09:49,  4.31s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#
/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  96%|█████████▌| 959/1000 [1:34:30<03:48,  5.57s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  96%|█████████▌| 960/1000 [1:34:34<03:19,  4.98s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  96%|█████████▌| 961/1000 [1:34:44<04:06,  6.32s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  96%|█████████▌| 962/1000 [1:34:48<03:44,  5.90s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  96%|█████████▋| 963/1000 [1:34:52<03:14,  5.26s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  96%|█████████▋| 964/1000 [1:34:57<03:00,  5.01s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  96%|█████████▋| 965/1000 [1:35:03<03:13,  5.54s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 966/1000 [1:35:09<03:10,  5.60s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 967/1000 [1:35:14<02:54,  5.28s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 968/1000 [1:35:18<02:38,  4.95s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 969/1000 [1:35:22<02:21,  4.56s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 970/1000 [1:35:27<02:25,  4.85s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 971/1000 [1:35:31<02:13,  4.60s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 972/1000 [1:35:34<01:57,  4.19s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 973/1000 [1:35:39<01:59,  4.43s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  97%|█████████▋| 974/1000 [1:35:51<02:55,  6.74s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 975/1000 [1:35:55<02:27,  5.90s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 976/1000 [1:35:59<02:07,  5.32s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 977/1000 [1:36:05<02:01,  5.29s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 978/1000 [1:36:10<01:58,  5.37s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 979/1000 [1:36:16<01:55,  5.50s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 980/1000 [1:36:28<02:26,  7.34s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 981/1000 [1:36:33<02:09,  6.82s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 982/1000 [1:36:38<01:51,  6.17s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 983/1000 [1:36:43<01:39,  5.83s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 984/1000 [1:36:48<01:28,  5.54s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  98%|█████████▊| 985/1000 [1:36:54<01:24,  5.66s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▊| 986/1000 [1:36:58<01:15,  5.36s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▊| 987/1000 [1:37:10<01:34,  7.28s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▉| 988/1000 [1:37:15<01:17,  6.50s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▉| 989/1000 [1:37:22<01:14,  6.77s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▉| 990/1000 [1:37:26<00:58,  5.82s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▉| 991/1000 [1:37:30<00:48,  5.35s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▉| 992/1000 [1:37:36<00:43,  5.41s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▉| 993/1000 [1:37:51<00:58,  8.35s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  99%|█████████▉| 994/1000 [1:37:59<00:49,  8.26s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# 100%|█████████▉| 995/1000 [1:38:06<00:39,  7.84s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# 100%|█████████▉| 996/1000 [1:38:10<00:26,  6.68s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# 100%|█████████▉| 997/1000 [1:38:14<00:18,  6.06s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# 100%|█████████▉| 998/1000 [1:38:22<00:13,  6.65s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# 100%|█████████▉| 999/1000 [1:38:32<00:07,  7.56s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# 100%|██████████| 1000/1000 [1:38:39<00:00,  5.92s/it]
# FaceSwap videos on disk: 986

# %%
import os

downloaded_files = set(os.listdir(faceswap_dest))

missing = []

for filename in sampled_faceswap:
    local_name = os.path.basename(filename)

    # Kaggle usually downloads as .zip
    if (local_name not in downloaded_files and
        local_name + ".zip" not in downloaded_files):
        missing.append(filename)

print(f"Missing files: {len(missing)}")
print(missing[:10])
# Out:
# Missing files: 14
# ['FaceForensics++_C23/FaceSwap/162_330.mp4', 'FaceForensics++_C23/FaceSwap/409_382.mp4', 'FaceForensics++_C23/FaceSwap/313_283.mp4', 'FaceForensics++_C23/FaceSwap/258_246.mp4', 'FaceForensics++_C23/FaceSwap/595_597.mp4', 'FaceForensics++_C23/FaceSwap/415_484.mp4', 'FaceForensics++_C23/FaceSwap/993_989.mp4', 'FaceForensics++_C23/FaceSwap/915_895.mp4', 'FaceForensics++_C23/FaceSwap/397_602.mp4', 'FaceForensics++_C23/FaceSwap/817_827.mp4']

# %%
print(f"Downloading {len(missing)} missing files...")

download_with_retry(missing, faceswap_dest, max_retries=10)

print("Finished!")
# Out:
# Downloading 14 missing files...
#   0%|          | 0/14 [00:00<?, ?it/s]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#   7%|▋         | 1/14 [00:04<01:03,  4.92s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  14%|█▍        | 2/14 [00:09<00:59,  4.96s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  21%|██▏       | 3/14 [00:14<00:51,  4.71s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  29%|██▊       | 4/14 [00:18<00:43,  4.34s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  36%|███▌      | 5/14 [00:22<00:40,  4.50s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  43%|████▎     | 6/14 [00:27<00:35,  4.38s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  50%|█████     | 7/14 [00:32<00:32,  4.61s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  57%|█████▋    | 8/14 [00:36<00:28,  4.69s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  64%|██████▍   | 9/14 [00:44<00:27,  5.56s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  71%|███████▏  | 10/14 [00:49<00:21,  5.34s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  79%|███████▊  | 11/14 [00:53<00:15,  5.02s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  86%|████████▌ | 12/14 [00:57<00:09,  4.82s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
#  93%|█████████▎| 13/14 [01:03<00:05,  5.08s/it]
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# 100%|██████████| 14/14 [01:08<00:00,  4.89s/it]
# Finished!

# %% [markdown]
# Step 2: Extract frames

# %%
import cv2

frames_faceswap = "D:/Deepfake-detection/datasets/frames_faceswap"
os.makedirs(frames_faceswap, exist_ok=True)
FRAMES_PER_VIDEO = 5

def extract_frames(video_path, output_folder, video_id, num_frames=5):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames <= 0:
        cap.release()
        return 0
    frame_indices = [int(i * total_frames / num_frames) for i in range(num_frames)]
    saved = 0
    for idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        success, frame = cap.read()
        if success:
            out_path = os.path.join(output_folder, f"{video_id}_frame{saved}.jpg")
            cv2.imwrite(out_path, frame)
            saved += 1
    cap.release()
    return saved

faceswap_videos = os.listdir(faceswap_dest)
total_saved = 0
for i, vid in enumerate(tqdm(faceswap_videos, desc="Extracting faceswap frames")):
    video_path = os.path.join(faceswap_dest, vid)
    saved = extract_frames(video_path, frames_faceswap, video_id=f"faceswap_{i}", num_frames=FRAMES_PER_VIDEO)
    total_saved += saved

print(f"Total faceswap frames saved: {total_saved}")
# Out:
# Extracting faceswap frames: 100%|██████████| 1000/1000 [26:40<00:00,  1.60s/it]
# Total faceswap frames saved: 4995

# %% [markdown]
# Step 3: Face-crop

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
IMG_SIZE = 224

def crop_face(image_path, output_path, img_size=IMG_SIZE):
    img = cv2.imread(image_path)
    if img is None:
        return "unreadable"
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(60, 60))
    if len(faces) > 0:
        faces = sorted(faces, key=lambda f: f[2] * f[3], reverse=True)
        x, y, w, h = faces[0]
        face_crop = img[y:y+h, x:x+w]
        method = "face_crop"
    else:
        face_crop = img
        method = "full_frame"
    face_resized = cv2.resize(face_crop, (img_size, img_size))
    cv2.imwrite(output_path, face_resized)
    return method

cropped_faceswap = "D:/Deepfake-detection/datasets/cropped_faceswap"
os.makedirs(cropped_faceswap, exist_ok=True)

def process_folder(input_folder, output_folder):
    files = os.listdir(input_folder)
    counts = {"face_crop": 0, "full_frame": 0, "unreadable": 0}
    for f in tqdm(files, desc=f"Processing {input_folder}"):
        in_path = os.path.join(input_folder, f)
        out_path = os.path.join(output_folder, f)
        result = crop_face(in_path, out_path)
        counts[result] += 1
    return counts

faceswap_counts = process_folder(frames_faceswap, cropped_faceswap)
print(f"FaceSwap: {faceswap_counts}, total processed: {sum(faceswap_counts.values())} / {len(os.listdir(frames_faceswap))}")
# Out:
# Processing D:/Deepfake-detection/datasets/frames_faceswap: 100%|██████████| 4995/4995 [11:11<00:00,  7.44it/s]
# FaceSwap: {'face_crop': 4971, 'full_frame': 24, 'unreadable': 0}, total processed: 4995 / 4995

# %% [markdown]
# Step 4: Build the 3-class dataset (real / other_fake / faceswap)

# %%
import shutil
random.seed(42)

dataset_base = "D:/Deepfake-detection/datasets"
faceswap_dataset_base = "D:/Deepfake-detection/datasets_faceswap"

def split_dataset(source_folder, dest_base, class_name, train_ratio=0.7, val_ratio=0.15):
    files = os.listdir(source_folder)
    random.shuffle(files)
    n = len(files)
    train_end = int(n * train_ratio)
    val_end = train_end + int(n * val_ratio)
    train_files = files[:train_end]
    val_files = files[train_end:val_end]
    test_files = files[val_end:]
    for split_name, split_files in [("train", train_files), ("validation", val_files), ("test", test_files)]:
        dest_folder = os.path.join(dest_base, split_name, class_name)
        os.makedirs(dest_folder, exist_ok=True)
        for f in split_files:
            shutil.copy(os.path.join(source_folder, f), os.path.join(dest_folder, f))
    print(f"{class_name}: train={len(train_files)}, val={len(val_files)}, test={len(test_files)}")

split_dataset(os.path.join(dataset_base, "cropped_real"), faceswap_dataset_base, "real")
split_dataset(os.path.join(dataset_base, "cropped_fake"), faceswap_dataset_base, "other_fake")
split_dataset(cropped_faceswap, faceswap_dataset_base, "faceswap")
# Out:
# real: train=3500, val=750, test=750
# other_fake: train=3500, val=750, test=750
# faceswap: train=3496, val=749, test=750

# %% [markdown]
# Step 5: Build the 3-class model

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

IMG_SIZE = 224
BATCH_SIZE = 8

transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_data = datasets.ImageFolder(f"{faceswap_dataset_base}/train", transform=transform)
val_data = datasets.ImageFolder(f"{faceswap_dataset_base}/validation", transform=transform)
test_data = datasets.ImageFolder(f"{faceswap_dataset_base}/test", transform=transform)

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

print("Classes:", train_data.classes)
print("Train size:", len(train_data), "Val size:", len(val_data), "Test size:", len(test_data))

model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
# Out:
# Using device: cuda
# Classes: ['faceswap', 'other_fake', 'real']
# Train size: 10496 Val size: 2249 Test size: 2250

# %% [markdown]
# Step 6: Train — with checkpoint-resume and early stopping

# %%
torch.set_num_threads(os.cpu_count())

ACCUMULATION_STEPS = 2
EPOCHS = 20
PATIENCE = 4
checkpoint_path = "D:/Deepfake-detection/saved_models/efficientnet_faceswap_best.pth"
resume_path = "D:/Deepfake-detection/saved_models/efficientnet_faceswap_resume.pth"

def train_one_epoch():
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    optimizer.zero_grad()
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels) / ACCUMULATION_STEPS
        loss.backward()
        if (i + 1) % ACCUMULATION_STEPS == 0:
            optimizer.step()
            optimizer.zero_grad()
        running_loss += loss.item() * ACCUMULATION_STEPS * images.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)
    if (i + 1) % ACCUMULATION_STEPS != 0:
        optimizer.step()
        optimizer.zero_grad()
    return running_loss / total, correct / total

def validate():
    model.eval()
    running_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
    return running_loss / total, correct / total

start_epoch = 0
best_val_acc = 0.0
epochs_without_improvement = 0

if os.path.exists(resume_path):
    checkpoint = torch.load(resume_path, map_location=device)
    model.load_state_dict(checkpoint["model_state"])
    optimizer.load_state_dict(checkpoint["optimizer_state"])
    start_epoch = checkpoint["epoch"] + 1
    best_val_acc = checkpoint["best_val_acc"]
    print(f"Resuming from epoch {start_epoch} (best_val_acc so far: {best_val_acc:.4f})")

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    train_loss, train_acc = train_one_epoch()
    val_loss, val_acc = validate()
    elapsed = time.time() - start

    print(f"Epoch {epoch+1}/{EPOCHS} | Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} | "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f} | Time: {elapsed:.1f}s")

    torch.save({
        "epoch": epoch,
        "model_state": model.state_dict(),
        "optimizer_state": optimizer.state_dict(),
        "best_val_acc": best_val_acc,
    }, resume_path)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        epochs_without_improvement = 0
        torch.save(model.state_dict(), checkpoint_path)
        print(f"  -> New best model saved (val_acc={val_acc:.4f})")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= PATIENCE:
            print(f"No improvement for {PATIENCE} epochs -- stopping early at epoch {epoch+1}.")
            break

print(f"Training complete. Best val_acc: {best_val_acc:.4f}")
# Out:
# Epoch 1/20 | Train Loss: 0.4426, Train Acc: 0.8160 | Val Loss: 0.1680, Val Acc: 0.9346 | Time: 464.6s
#   -> New best model saved (val_acc=0.9346)
# Epoch 2/20 | Train Loss: 0.1986, Train Acc: 0.9269 | Val Loss: 0.1312, Val Acc: 0.9520 | Time: 271.0s
#   -> New best model saved (val_acc=0.9520)
# Epoch 3/20 | Train Loss: 0.1297, Train Acc: 0.9545 | Val Loss: 0.1058, Val Acc: 0.9555 | Time: 224.0s
#   -> New best model saved (val_acc=0.9555)
# Epoch 4/20 | Train Loss: 0.0931, Train Acc: 0.9661 | Val Loss: 0.1095, Val Acc: 0.9564 | Time: 222.5s
#   -> New best model saved (val_acc=0.9564)
# Epoch 5/20 | Train Loss: 0.0720, Train Acc: 0.9727 | Val Loss: 0.1171, Val Acc: 0.9524 | Time: 232.5s
# Epoch 6/20 | Train Loss: 0.0582, Train Acc: 0.9787 | Val Loss: 0.1126, Val Acc: 0.9604 | Time: 220.8s
#   -> New best model saved (val_acc=0.9604)
# Epoch 7/20 | Train Loss: 0.0541, Train Acc: 0.9791 | Val Loss: 0.1186, Val Acc: 0.9520 | Time: 222.6s
# Epoch 8/20 | Train Loss: 0.0528, Train Acc: 0.9816 | Val Loss: 0.1129, Val Acc: 0.9546 | Time: 199.3s
# Epoch 9/20 | Train Loss: 0.0409, Train Acc: 0.9856 | Val Loss: 0.1309, Val Acc: 0.9533 | Time: 196.2s
